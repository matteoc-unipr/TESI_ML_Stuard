# %% [markdown]
# <h2> LSTM Models <h2>

# %% [markdown]
# Create various LSTM Models and evaluating them<br>
#
# **NOTE: Using a dataset with 10 of the best performing feature based on another student analysis**

# %% [markdown]
# **Features (x):**<br>
# - *soil_vwc*
# - *soil_ec*
# - *irrigation_24h*
# - *irrigation_36h*
# - *irrigation_48h*
# - *relative_humidity_ds_24h*
# - *relative_humidity_ds_36h*
# - *relative_humidity_ds_48h*
# - *precipitation_36h*
# - *precipitation_24h*
# - *precipitation_48h*
#
# **Target (y)** is *soil_vwc*
#
# <br><br>

# %% [markdown]
# Reading the dataset file

# %%
import pandas as pd

# reading the ds file
df_scaled = pd.read_excel("./2023-stuard/df_best_scaled.xlsx", index_col=0)

# %%
df_scaled
# Out:
#                      soil_vwc   soil_ec  irrigation_24h  irrigation_36h  \
# timestamp
# 2023-07-11 10:10:00 -0.211271 -0.568325       -0.546472       -0.697505
# 2023-07-11 10:20:00 -0.162457 -0.446523       -0.546472       -0.697505
# 2023-07-11 10:30:00 -0.143942 -0.389065       -0.546472       -0.697505
# 2023-07-11 10:40:00 -0.123743 -0.360037       -0.546472       -0.697505
# 2023-07-11 10:50:00 -0.118693 -0.350317       -0.546472       -0.697505
# ...                       ...       ...             ...             ...
# 2023-09-19 23:10:00 -0.446924 -0.722202       -0.546472       -0.697505
# 2023-09-19 23:20:00 -0.448607 -0.722202       -0.546472       -0.697505
# 2023-09-19 23:30:00 -0.446924 -0.722202       -0.546472       -0.697505
# 2023-09-19 23:40:00 -0.445241 -0.713316       -0.546472       -0.697505
# 2023-09-19 23:50:00 -0.445241 -0.722202       -0.546472       -0.697505
#
#                      irrigation_48h  relative_humidity_ds_24h  \
# timestamp
# 2023-07-11 10:10:00       -0.850408                  0.635486
# 2023-07-11 10:20:00       -0.850408                  0.612772
# 2023-07-11 10:30:00       -0.850408                  0.578156
# 2023-07-11 10:40:00       -0.850408                  0.537642
# 2023-07-11 10:50:00       -0.850408                  0.505280
# ...                             ...                       ...
# 2023-09-19 23:10:00       -0.850408                  0.969098
# 2023-09-19 23:20:00       -0.850408                  0.958112
# 2023-09-19 23:30:00       -0.850408                  0.946782
# 2023-09-19 23:40:00       -0.850408                  0.934079
# 2023-09-19 23:50:00       -0.850408                  0.920690
#
#                      relative_humidity_ds_36h  relative_humidity_ds_48h  \
# timestamp
# 2023-07-11 10:10:00                  0.676346                  0.719121
# 2023-07-11 10:20:00                  0.652443                  0.693960
# 2023-07-11 10:30:00                  0.616018                  0.655617
# 2023-07-11 10:40:00                  0.573385                  0.610740
# 2023-07-11 10:50:00                  0.539330                  0.574893
# ...                                       ...                       ...
# 2023-09-19 23:10:00                  0.898885                  1.135242
# 2023-09-19 23:20:00                  0.885717                  1.129158
# 2023-09-19 23:30:00                  0.873174                  1.122946
# 2023-09-19 23:40:00                  0.861515                  1.116228
# 2023-09-19 23:50:00                  0.850664                  1.109383
#
#                      precipitation_36h  precipitation_24h  precipitation_48h
# timestamp
# 2023-07-11 10:10:00          -0.319756          -0.267801          -0.362414
# 2023-07-11 10:20:00          -0.319756          -0.267801          -0.362414
# 2023-07-11 10:30:00          -0.319756          -0.267801          -0.362414
# 2023-07-11 10:40:00          -0.319756          -0.267801          -0.362414
# 2023-07-11 10:50:00          -0.319756          -0.267801          -0.362414
# ...                                ...                ...                ...
# 2023-09-19 23:10:00          -0.319756          -0.267801          -0.362414
# 2023-09-19 23:20:00          -0.319756          -0.267801          -0.362414
# 2023-09-19 23:30:00          -0.319756          -0.267801          -0.362414
# 2023-09-19 23:40:00          -0.319756          -0.267801          -0.362414
# 2023-09-19 23:50:00          -0.319756          -0.267801          -0.362414
#
# [10151 rows x 11 columns]

# %% [markdown]
# <h3> Organizing data in time series <h3>

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator


# Time Series Parameters
WINDOW = 5
SPLIT = 0.8
SAMPLING_RATE = 1
BATCH_SIZE = 1



features=df_scaled
target=df_scaled['soil_vwc'] 
t_size = 1 - SPLIT

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=t_size, random_state=123, shuffle=False)
train_generator = TimeseriesGenerator( x_train, y_train, length=WINDOW,sampling_rate=SAMPLING_RATE, batch_size=BATCH_SIZE)
test_generator = TimeseriesGenerator( x_test, y_test, length=WINDOW,sampling_rate=SAMPLING_RATE, batch_size=BATCH_SIZE )
train_generator[0]
# Out:
# (array([[[-0.21127124, -0.56832529, -0.54647248, -0.69750535,
#           -0.85040843,  0.6354863 ,  0.67634596,  0.71912063,
#           -0.31975597, -0.26780144, -0.36241371],
#          [-0.16245744, -0.44652314, -0.54647248, -0.69750535,
#           -0.85040843,  0.61277166,  0.65244339,  0.69395999,
#           -0.31975597, -0.26780144, -0.36241371],
#          [-0.14394185, -0.38906519, -0.54647248, -0.69750535,
#           -0.85040843,  0.57815639,  0.61601781,  0.65561722,
#           -0.31975597, -0.26780144, -0.36241371],
#          [-0.12374304, -0.36003717, -0.54647248, -0.69750535,
#           -0.85040843,  0.53764236,  0.57338497,  0.61074048,
#           -0.31975597, -0.26780144, -0.36241371],
#          [-0.11869333, -0.35031651, -0.54647248, -0.69750535,
#           -0.85040843,  0.50528004,  0.53933016,  0.57489325,
#           -0.31975597, -0.26780144, -0.36241371]]]),
#  array([-0.11532686]))

# %%
x_train.shape
# Out:
# (8120, 11)

# %%
x_test.shape
# Out:
# (2031, 11)

# %% [markdown]
# ## Building LSTM Model

# %%
import keras

lstm_model1 = keras.Sequential()
lstm_model1.add(keras.layers.LSTM(8, input_shape= (WINDOW, 11), return_sequences= False))

lstm_model1.add(keras.layers.Dense(1))

# %%
lstm_model1.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 8)                   │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 649 (2.54 KB)
#  Trainable params: 649 (2.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam

lstm_model1.compile(loss = 'MeanSquaredError', metrics = ['MAE'], optimizer = Adam(learning_rate = 0.001)) 
history = lstm_model1.fit(train_generator, epochs=50, validation_data=test_generator, shuffle=False)
# Out:
# Epoch 1/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - MAE: 0.0920 - loss: 0.0334 - val_MAE: 0.3904 - val_loss: 0.2240
# Epoch 2/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - MAE: 0.0703 - loss: 0.0182 - val_MAE: 0.1201 - val_loss: 0.0260
# Epoch 3/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - MAE: 0.0571 - loss: 0.0121 - val_MAE: 0.0638 - val_loss: 0.0080
# Epoch 4/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - MAE: 0.0500 - loss: 0.0105 - val_MAE: 0.1101 - val_loss: 0.0205
# Epoch 5/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - MAE: 0.0442 - loss: 0.0084 - val_MAE: 0.1284 - val_loss: 0.0317
# Epoch 6/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - MAE: 0.0392 - loss: 0.0065 - val_MAE: 0.2170 - val_loss: 0.0733
# Epoch 7/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - MAE: 0.0339 - loss: 0.0046 - val_MAE: 0.1959 - val_loss: 0.0749
# Epoch 8/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - MAE: 0.
50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - MAE: 0.0208 - loss: 0.0018 - val_MAE: 0.1279 - val_loss: 0.0208
# Epoch 39/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - MAE: 0.0197 - loss: 0.0015 - val_MAE: 0.1157 - val_loss: 0.0189
# Epoch 40/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - MAE: 0.0211 - loss: 0.0017 - val_MAE: 0.0636 - val_loss: 0.0094
# Epoch 41/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - MAE: 0.0196 - loss: 0.0014 - val_MAE: 0.0920 - val_loss: 0.0120
# Epoch 42/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - MAE: 0.0213 - loss: 0.0017 - val_MAE: 0.0973 - val_loss: 0.0128
# Epoch 43/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - MAE: 0.0204 - loss: 0.0016 - val_MAE: 0.1006 - val_loss: 0.0165
# Epoch 44/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - MAE: 0.0204 - loss: 0.0017 - val_MAE: 0.0372 - val_loss: 0.0020
# Epoch 45/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - MAE: 0.0191 - loss: 0.0014 - val_MAE: 0.0514 - val_loss: 0.0035
# Epoch 46/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - MAE: 0.0202 - loss: 0.0017 - val_MAE: 0.0875 - val_loss: 0.0094
# Epoch 47/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 26s 3ms/step - MAE: 0.0198 - loss: 0.0015 - val_MAE: 0.0818 - val_loss: 0.0097
# Epoch 48/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - MAE: 0.0190 - loss: 0.0014 - val_MAE: 0.0516 - val_loss: 0.0066
# Epoch 49/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - MAE: 0.0196 - loss: 0.0016 - val_MAE: 0.0518 - val_loss: 0.0039
# Epoch 50/50
# 8115/8115 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - MAE: 0.0208 - loss: 0.0018 - val_MAE: 0.0647 - val_loss: 0.0061

# %%
lstm_model1.evaluate(test_generator, verbose=0)
# Out:
# [0.006065803579986095, 0.06474777311086655]

# %%
predictions=lstm_model1.predict(test_generator)
# Out:
# 2026/2026 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step

# %%
predictions.shape[0]
# Out:
# 2026

# %%
predictions
# Out:
# array([[-0.00355233],
#        [-0.00612921],
#        [-0.01167025],
#        ...,
#        [-0.56078506],
#        [-0.5592885 ],
#        [-0.55771035]], dtype=float32)

# %%
y_test
# Out:
# timestamp
# 2023-09-05 19:30:00    0.002500
# 2023-09-05 19:40:00    0.004183
# 2023-09-05 19:50:00   -0.002550
# 2023-09-05 20:00:00   -0.000867
# 2023-09-05 20:10:00    0.004183
#                          ...
# 2023-09-19 23:10:00   -0.446924
# 2023-09-19 23:20:00   -0.448607
# 2023-09-19 23:30:00   -0.446924
# 2023-09-19 23:40:00   -0.445241
# 2023-09-19 23:50:00   -0.445241
# Name: soil_vwc, Length: 2031, dtype: float64

# %%
x_test
# Out:
#                      soil_vwc   soil_ec  irrigation_24h  irrigation_36h  \
# timestamp
# 2023-09-05 19:30:00  0.002500  0.132748       -0.546472       -0.697505
# 2023-09-05 19:40:00  0.004183  0.132748       -0.546472       -0.697505
# 2023-09-05 19:50:00 -0.002550  0.132748       -0.546472       -0.697505
# 2023-09-05 20:00:00 -0.000867  0.121916       -0.546472       -0.697505
# 2023-09-05 20:10:00  0.004183  0.132748       -0.546472       -0.697505
# ...                       ...       ...             ...             ...
# 2023-09-19 23:10:00 -0.446924 -0.722202       -0.546472       -0.697505
# 2023-09-19 23:20:00 -0.448607 -0.722202       -0.546472       -0.697505
# 2023-09-19 23:30:00 -0.446924 -0.722202       -0.546472       -0.697505
# 2023-09-05 20:30:00                 -0.832049                 -0.541570
# 2023-09-05 20:40:00                 -0.829656                 -0.549013
# 2023-09-05 20:50:00                 -0.827157                 -0.556321
# 2023-09-05 21:00:00                 -0.824832                 -0.563383
# ...                                       ...                       ...
# 2023-09-19 23:10:00                  0.969098                  0.898885
# 2023-09-19 23:20:00                  0.958112                  0.885717
# 2023-09-19 23:30:00                  0.946782                  0.873174
# 2023-09-19 23:40:00                  0.934079                  0.861515
# 2023-09-19 23:50:00                  0.920690                  0.850664
#
#                      relative_humidity_ds_48h  precipitation_36h  \
# timestamp
# 2023-09-05 20:20:00                 -0.225509          -0.319756
# 2023-09-05 20:30:00                 -0.228871          -0.319756
# 2023-09-05 20:40:00                 -0.232178          -0.319756
# 2023-09-05 20:50:00                 -0.235485          -0.319756
# 2023-09-05 21:00:00                 -0.238891          -0.319756
# ...                                       ...                ...
# 2023-09-19 23:10:00                  1.135242          -0.319756
# 2023-09-19 23:20:00                  1.129158          -0.319756
# 2023-09-19 23:30:00                  1.122946          -0.319756
# 2023-09-19 23:40:00                  1.116228          -0.319756
# 2023-09-19 23:50:00                  1.109383          -0.319756
#
#                      precipitation_24h  precipitation_48h
# timestamp
# 2023-09-05 20:20:00          -0.267801          -0.362414
# 2023-09-05 20:30:00          -0.267801          -0.362414
# 2023-09-05 20:40:00          -0.267801          -0.362414
# 2023-09-05 20:50:00          -0.267801          -0.362414
# 2023-09-05 21:00:00          -0.267801          -0.362414
# ...                                ...                ...
# 2023-09-19 23:10:00          -0.267801          -0.362414
# 2023-09-19 23:20:00          -0.267801          -0.362414
# 2023-09-19 23:30:00          -0.267801          -0.362414
# 2023-09-19 23:40:00          -0.267801          -0.362414
# 2023-09-19 23:50:00          -0.267801          -0.362414
#
# [2026 rows x 10 columns]

# %%
df_pred=pd.concat([pd.DataFrame(predictions), pd.DataFrame(x_test.iloc[:, 1:][WINDOW:])], axis=1)

# %%
rev_trans=scaler.inverse_transform(df_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 rev_trans=scaler.inverse_transform(df_pred)
#
# NameError: name 'scaler' is not defined

# %%
# isolating the timestamp column to merge with the predictions in a second moment
df_copy = df_scaled
df_copy = df_copy.reset_index()
df_copy = df_copy[['timestamp']]

# %%
# TRAIN DATA VISUALIZATION

train_predictions = lstm_model1.predict(X_train).flatten()
y_train = y_train.flatten()

# Ensure df_copy contains the 'timestamp' column
timestamp_training = df_copy['timestamp'].iloc[:int(SPLIT * len(X_temp))]
train_results = pd.DataFrame(data={'timestamp':timestamp_training, 'Train Predictions':train_predictions, 'Actuals':y_train})

# Plot the test results
plt.figure(figsize=(12, 5))
plt.plot(train_results['timestamp'], train_results['Actuals'], label='Actuals')
plt.plot(train_results['timestamp'], train_results['Train Predictions'], label='Train Predictions')

# Format x-axis to show only dates
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval= 2))  # Adjusts to show ticks daily

ax = plt.gca()  
ax.xaxis.grid(which="major", color="black", linestyle="--", alpha=0.3)  # Set x-axis grid

plt.xlabel('Time')
plt.ylabel('Volumetric Water Content Scaled')
plt.title('Train Predictions vs. Actuals')
plt.legend(['Actuals', 'Train Predictions'])
plt.xticks(rotation=45)  # Rotate the x-axis labels if they overlap
plt.show()
